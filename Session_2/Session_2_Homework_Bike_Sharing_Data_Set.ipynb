# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("C:/Users/Ecem/Desktop/BTS/BTS_MasterInBigData-master/Session_2/3_bike_sharing.csv")
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
# datetime      10886 non-null object
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# weather       10886 non-null int64
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# casual        10886 non-null int64
# registered    10886 non-null int64
# count         10886 non-null int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.6+ KB

# %%
df.shape
# Out:
# (10886, 12)

# %%
df.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
df.dtypes
# Out:
# datetime       object
# season          int64
# holiday         int64
# workingday      int64
# weather         int64
# temp          float64
# atemp         float64
# humidity        int64
# windspeed     float64
# casual          int64
# registered      int64
# count           int64
# dtype: object

# %% [markdown]
# ###How many avarage rental each season?

# %%
a=df.groupby("season")["count"].mean()
a
# Out:
# season
# 1    116.343261
# 2    215.251372
# 3    234.417124
# 4    198.988296
# Name: count, dtype: float64

# %% [markdown]
# ##Which season have a max rental?

# %%
b=max(a)    #### Merge needed for this questions:) and looking at the manual we see that fall
b
# Out:
# 234.41712403951701

# %% [markdown]
# how many record on the day of holiday ?

# %%
[df.loc[:,"holiday"]==1].shape
# Out:
# (311, 12)

# %% [markdown]
# the average rental of casual in each weather category

# %%
c=df.groupby("weather")["casual"].mean()
c
# Out:
# weather
# 1    40.308676
# 2    30.785462
# 3    17.442375
# 4     6.000000
# Name: casual, dtype: float64

# %% [markdown]
# #the average rental of registered in each season

# %%
d=df.groupby("season")["registered"].mean()
d
# Out:
# weather
# 1    164.928115
# 2    148.170078
# 3    101.403958
# 4    158.000000
# Name: registered, dtype: float64

# %% [markdown]
# the total number of rentals at each date

# %%
e=df.groupby("datetime")["count"].max()
e
# Out:
# datetime
# 2011-01-01 00:00:00     16
# 2011-01-01 01:00:00     40
# 2011-01-01 02:00:00     32
# 2011-01-01 03:00:00     13
# 2011-01-01 04:00:00      1
# 2011-01-01 05:00:00      1
# 2011-01-01 06:00:00      2
# 2011-01-01 07:00:00      3
# 2011-01-01 08:00:00      8
# 2011-01-01 09:00:00     14
# 2011-01-01 10:00:00     36
# 2011-01-01 11:00:00     56
# 2011-01-01 12:00:00     84
# 2011-01-01 13:00:00     94
# 2011-01-01 14:00:00    106
# 2011-01-01 15:00:00    110
# 2011-01-01 16:00:00     93
# 2011-01-01 17:00:00     67
# 2011-01-01 18:00:00     35
# 2011-01-01 19:00:00     37
# 2011-01-01 20:00:00     36
# 2011-01-01 21:00:00     34
# 2011-01-01 22:00:00     28
# 2011-01-01 23:00:00     39
# 2011-01-02 00:00:00     17
# 2011-01-02 01:00:00     17
# 2011-01-02 02:00:00      9
# 2011-01-02 03:00:00      6
# 2011-01-02 04:00:00      3
# 2011-01-02 06:00:00      2
#                       ...
# 2012-12-18 18:00:00    525
# 2012-12-18 19:00:00    353
# 2012-12-18 20:00:00    268
# ...

# %% [markdown]
# Counter Plot of "workingday"

# %%
plt.figure(figsize=[12,10]) 
sns.countplot(df['workingday']) 
plt.show()

# %% [markdown]
# almost 2/3 of the data set shows the number of working days rental.

# %%
plt.figure(figsize=[12,10])
sns.swarmplot(x="season",y="registered",data=df)
plt.show()

# %%
plt.figure(figsize=[12,10])
sns.factorplot("season","count","weather",data=df,kind="bar",palette="muted",legend=True)
plt.show()
