# %%
import pandas as pd
df=pd.read_csv("C:/Users/Ecem/Desktop/BTS/BTS_MasterInBigData-master/Session_1/file_formats/rural_population_data.csv",names=["Continent","ElevationZone","UrbanRuralDesignation","Population1990","Population2000","Population2010","Population2100","LandArea"],skiprows=1)
df.head()
# Out:
#   Continent                          ElevationZone UrbanRuralDesignation  \
# 0    Africa    Elevations > 20m or Non-Contiguous                  Rural
# 1    Africa    Elevations > 20m or Non-Contiguous                  Urban
# 2    Africa  Elevations Less Than or Equal To 10m                  Rural
# 3    Africa  Elevations Less Than or Equal To 10m                  Urban
# 4    Africa  Elevations Less Than or Equal To 12m                  Rural
#
#    Population1990  Population2000  Population2010  Population2100  LandArea
# 0       333302081       418265923       530184094      1249908321  23749644
# 1       157846329       210381843       266776037       504662423    204719
# 2        18167003        22569516        28154645        76368900    172460
# 3        22412955        28679117        36746774        94042536     13838
# 4        20569411        25576481        31957186        85839163    202456

# %%
df["Continent"].unique()
# Out:
# array(['Africa', 'Asia', 'Oceania', 'Europe', 'North America',
#        'South America'], dtype=object)

# %%
df["grow rate"]=(df["Population2100"] - df["Population2000"]) / df["Population2000"]
df["grow rate"]
# Out:
# 0      1.988310
# 1      1.398793
# 2      2.383719
# 3      2.279129
# 4      2.356176
# 5      2.212735
# 6      2.636647
# 7      3.411567
# 8      2.401295
# 9      2.041775
# 10     2.533266
# 11     2.968851
# 12     2.491768
# 13     2.693091
# 14     2.441114
# 15     2.472450
# 16     2.400774
# 17     2.325991
# 18     2.019951
# 19     1.517733
# 20     0.598382
# 21     0.501763
# 22     0.779678
# 23     0.495082
# 24     0.799481
# 25     0.502617
# 26     0.608838
# 27     0.389177
# 28     0.822584
# 29     0.518478
#          ...
# 90     0.496656
# 91     0.376791
# 92     0.537458
# 93     0.376910
# 94     0.557176
# 95     0.433418
# 96     0.565522
# 97     0.659329
# 98     0.960744
# 99     0.389169
# 100    0.868260
# 101    0.867027
# 102    1.087785
# 103    0.912048
# 104    1.084155
# 105    0.910401
# 106    0.942667
# 107    0.833248
# 108    1.085945
# 109    0.878852
# 110    1.004640
# 111    0.735670
# 112    1.027591
# 113    0.871948
# ...

# %%
import matplotlib.pyplot as plt
df["grow rate"].hist()

# %%
df.isnull().sum()   #totally null rows
# Out:
# Continent                0
# ElevationZone            0
# UrbanRuralDesignation    0
# Population1990           0
# Population2000           0
# Population2010           0
# Population2100           0
# LandArea                 0
# grow rate                0
# dtype: int64

# %%
a=df["Population2000"].mean()
a
# Out:
# 120539097.45

# %%
b=df["Population2010"].mean()
b
# Out:
# 136698712.40833333

# %%
c=(a+b)/2
c
# Out:
# 128618904.92916667

# %%
d=df.loc[df.loc[:,"UrbanRuralDesignation"]=="Urban"]
d
# Out:
#          Continent                          ElevationZone  \
# 1           Africa    Elevations > 20m or Non-Contiguous
# 3           Africa  Elevations Less Than or Equal To 10m
# 5           Africa  Elevations Less Than or Equal To 12m
# 7           Africa    Elevations Less Than or Equal To 1m
# 9           Africa  Elevations Less Than or Equal To 20m
# 11          Africa    Elevations Less Than or Equal To 3m
# 13          Africa    Elevations Less Than or Equal To 5m
# 15          Africa    Elevations Less Than or Equal To 7m
# 17          Africa    Elevations Less Than or Equal To 9m
# 19          Africa              Total National Population
# 21            Asia    Elevations > 20m or Non-Contiguous
# 23            Asia  Elevations Less Than or Equal To 10m
# 25            Asia  Elevations Less Than or Equal To 12m
# 27            Asia    Elevations Less Than or Equal To 1m
# 29            Asia  Elevations Less Than or Equal To 20m
# ...

# %%
df.shape       #how is calcualte just row number?
# Out:
# (120, 9)
